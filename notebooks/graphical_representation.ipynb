# %%
import pandas as pd

# %%
df = pd.read_csv('data/processed/market_cap_crypto.csv')
df.tail(5)
# Out:
#                        datetime  raiden-network-token  gamecredits  smartcash  \
# 3090  2021-10-13 00:00:00+00:00            43682774.0   20746232.0  8089562.0
# 3091  2021-10-14 00:00:00+00:00            42530120.0   21033068.0  8226850.0
# 3092  2021-10-15 00:00:00+00:00            42347433.0   21176373.0  8412939.0
# 3093  2021-10-16 00:00:00+00:00            42345217.0   22109528.0  8219680.0
# 3094  2021-10-17 00:00:00+00:00            42386014.0   22392552.0  8185746.0
#
#       razor-network  bitcoin-cash        digg     airswap  nebula-ai  \
# 3090      8535737.0  1.121932e+10  26602309.0  35469210.0        0.0
# 3091      9708032.0  1.127849e+10  28294421.0  37000609.0        0.0
# 3092     10011209.0  1.178646e+10  30620093.0  35973259.0        0.0
# 3093      9414049.0  1.182135e+10  32222161.0  37977418.0        0.0
# 3094      9096453.0  1.175394e+10  30620007.0  37395694.0        0.0
#
#       bitnation  ...  measurable-data-token  visor-finance  valuechain  \
# ...
